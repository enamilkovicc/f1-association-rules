# %%
import sqlite3
import pandas as pd
import nbimporter

# %%
from final_scores import calculate_final_driver_places 
from lap_times_functions import get_lap_times_stats
from lap_times_functions import get_median_lap_position
from lap_times_functions import get_total_laps_count
from pit_stop_functions import get_pit_stop_stats_in_miliseconds
from pit_stop_functions import get_most_common_pit_stop_lap
from constructor_table import get_drivers_with_constructor_relationship
from constructor_table import get_constructor_points
from drivers_functions import get_age_at_first_race
from circuits_functions import get_best_performing_circuits
from results_functions import get_most_common_positions

# %%
conn = sqlite3.connect('formula1.db')

# %%
drivers_final_positions = calculate_final_driver_places(conn)
print(drivers_final_positions)
# Out:
#       year  driverId date_of_birth driver_nationality  driver_points  \
# 73    1950       642    1906-10-30            Italian           30.0
# 66    1950       579    1911-06-24          Argentine           27.0
# 72    1950       786    1898-06-09            Italian           24.0
# 70    1950       627    1905-11-05             French           13.0
# 56    1950       647    1918-07-13            Italian           11.0
# ...    ...       ...           ...                ...            ...
# 3133  2022       855    1999-05-30            Chinese            6.0
# 3136  2022       848    1996-03-23               Thai            4.0
# 3139  2022       849    1995-06-29           Canadian            2.0
# 3145  2022       856    1995-02-06              Dutch            2.0
# 3140  2022       807    1987-08-19             German            0.0
#
#       driver_end_position
# 73                      1
# 66                      2
# 72                      3
# 70                      4
# 56                      5
# ...                   ...
# 3133                   18
# 3136                   19
# 3139                   20
# 3145                   20
# 3140                   22
#
# [3146 rows x 6 columns]

# %%
drivers_final_positions = drivers_final_positions.sort_values(by=['year', 'driverId'])

for index, row in drivers_final_positions.iterrows():
    temp_df = drivers_final_positions[(drivers_final_positions['driverId'] == row['driverId']) & (drivers_final_positions['year'] <= row['year'])]
    
    first_place_count = temp_df[temp_df['driver_end_position'] == 1].shape[0]
    second_place_count = temp_df[temp_df['driver_end_position'] == 2].shape[0]
    third_place_count = temp_df[temp_df['driver_end_position'] == 3].shape[0]
    top_5_count = temp_df[temp_df['driver_end_position'] <= 5].shape[0]

    drivers_final_positions.at[index, 'first_place_count'] = first_place_count
    drivers_final_positions.at[index, 'second_place_count'] = second_place_count
    drivers_final_positions.at[index, 'third_place_count'] = third_place_count
    drivers_final_positions.at[index, 'top_5_count'] = top_5_count

print(drivers_final_positions)
# Out:
#       year  driverId date_of_birth driver_nationality  driver_points  \
# 51    1950       427    1917-10-30             French            0.0
# 53    1950       498    1922-10-05          Argentine            0.0
# 49    1950       501    1921-06-29           American            0.0
# 25    1950       509    1928-07-16           American            0.0
# 37    1950       518    1913-05-05           American            0.0
# ...    ...       ...           ...                ...            ...
# 3139  2022       849    1995-06-29           Canadian            2.0
# 3131  2022       852    2000-05-11           Japanese           12.0
# 3134  2022       854    1999-03-22             German           12.0
# 3133  2022       855    1999-05-30            Chinese            6.0
# 3145  2022       856    1995-02-06              Dutch            2.0
#
#       driver_end_position  first_place_count  second_place_count  \
# 51                     23                0.0                 0.0
# 53                     23                0.0                 0.0
# 49                     23                0.0                 0.0
# 25                     23                0.0                 0.0
# 37                     23                0.0                 0.0
# ...                   ...                ...                 ...
# 3139                   20                0.0                 0.0
# 3131                   16                0.0                 0.0
# 3134                   16                0.0                 0.0
# 3133                   18                0.0                 0.0
# 3145                   20                0.0                 0.0
#
#       third_place_count  top_5_count
# 51                  0.0          0.0
# 53                  0.0          0.0
# 49                  0.0          0.0
# 25                  0.0          0.0
# 37                  0.0          0.0
# ...                 ...          ...
# 3139                0.0          0.0
# 3131                0.0          0.0
# 3134                0.0          0.0
# 3133                0.0          0.0
# 3145                0.0          0.0
#
# [3146 rows x 10 columns]

# %%
driver_years = get_age_at_first_race(conn)
drivers_final_positions = pd.merge(drivers_final_positions, driver_years, on=['driverId'], how='left')

# %%
lap_times_stats = get_lap_times_stats(conn)
print(lap_times_stats)
# Out:
#      year  driverId  min_lap_time_diff  avg_lap_time_diff  max_lap_time_diff
# 0    2007         1           0.000000           7.852700        1465.791089
# 1    2008         1           0.000000           7.666610         101.287948
# 2    2009         1           0.074346           6.171578          79.374498
# 3    2010         1           0.000000          10.709896        2567.450593
# 4    2011         1           0.000000           8.270089        1600.104940
# ..    ...       ...                ...                ...                ...
# 642  2021       853           2.817997          21.635194        2443.049302
# 643  2021       854           2.234354          18.256438        2428.528386
# 644  2022       854           0.704944          14.242761        3432.659375
# 645  2022       855           0.000000          12.770114        1625.453523
# 646  2022       856           3.086993           8.555862          46.221588
#
# [647 rows x 5 columns]

# %%
columns_to_discretize = ['min_lap_time_diff', 'avg_lap_time_diff', 'max_lap_time_diff']
labels = ['0-25%', '25-50%', '50% and more']

for col in columns_to_discretize:
    if col == 'min_lap_time_diff':
        custom_bin_edges = [lap_times_stats[col].min(), 0.1, lap_times_stats[col].quantile(0.5), lap_times_stats[col].max()]
        lap_times_stats[col] = pd.cut(lap_times_stats[col], bins=custom_bin_edges, include_lowest=True, duplicates='drop', labels=labels)
    else:
        bin_edges = [lap_times_stats[col].min(), lap_times_stats[col].quantile(0.25), lap_times_stats[col].quantile(0.5), lap_times_stats[col].max()]
        lap_times_stats[col] = pd.cut(lap_times_stats[col], bins=bin_edges, include_lowest=True, duplicates='drop', labels=labels)

print(lap_times_stats)
# Out:
#      year  driverId min_lap_time_diff avg_lap_time_diff max_lap_time_diff
# 0    2007         1             0-25%            25-50%      50% and more
# 1    2008         1             0-25%            25-50%            25-50%
# 2    2009         1             0-25%             0-25%             0-25%
# 3    2010         1             0-25%      50% and more      50% and more
# 4    2011         1             0-25%            25-50%      50% and more
# ..    ...       ...               ...               ...               ...
# 642  2021       853      50% and more      50% and more      50% and more
# 643  2021       854      50% and more      50% and more      50% and more
# 644  2022       854            25-50%      50% and more      50% and more
# 645  2022       855             0-25%      50% and more      50% and more
# 646  2022       856      50% and more            25-50%             0-25%
#
# [647 rows x 5 columns]

# %%
lap_positions = get_median_lap_position(conn)
lap_times_stats = pd.merge(lap_times_stats, lap_positions, on=['driverId', 'year'], how='left')
print(lap_times_stats)
# Out:
#      year  driverId min_lap_time_diff avg_lap_time_diff max_lap_time_diff  \
# 0    2007         1             0-25%            25-50%      50% and more
# 1    2008         1             0-25%            25-50%            25-50%
# 2    2009         1             0-25%             0-25%             0-25%
# 3    2010         1             0-25%      50% and more      50% and more
# 4    2011         1             0-25%            25-50%      50% and more
# ..    ...       ...               ...               ...               ...
# 642  2021       853      50% and more      50% and more      50% and more
# 643  2021       854      50% and more      50% and more      50% and more
# 644  2022       854            25-50%      50% and more      50% and more
# 645  2022       855             0-25%      50% and more      50% and more
# 646  2022       856      50% and more            25-50%             0-25%
#
#      median_lap_position
# 0                      2
# 1                      3
# 2                      7
# 3                      4
# 4                      4
# ..                   ...
# 642                   18
# 643                   18
# 644                   14
# 645                   14
# 646                    9
#
# [647 rows x 6 columns]

# %%
lap_count = get_total_laps_count(conn)
lap_times_stats = pd.merge(lap_times_stats, lap_count, on=['driverId', 'year'], how='left')
print(lap_times_stats)
# Out:
#      year  driverId min_lap_time_diff avg_lap_time_diff max_lap_time_diff  \
# 0    2007         1             0-25%            25-50%      50% and more
# 1    2008         1             0-25%            25-50%            25-50%
# 2    2009         1             0-25%             0-25%             0-25%
# 3    2010         1             0-25%      50% and more      50% and more
# 4    2011         1             0-25%            25-50%      50% and more
# ..    ...       ...               ...               ...               ...
# 642  2021       853      50% and more      50% and more      50% and more
# 643  2021       854      50% and more      50% and more      50% and more
# 644  2022       854            25-50%      50% and more      50% and more
# 645  2022       855             0-25%      50% and more      50% and more
# 646  2022       856      50% and more            25-50%             0-25%
#
#      median_lap_position  total_laps
# 0                      2        1037
# 1                      3        1065
# 2                      7         904
# 3                      4        1001
# 4                      4        1013
# ..                   ...         ...
# 642                   18        1008
# 643                   18        1135
# 644                   14        1142
# 645                   14        1060
# 646                    9          53
#
# [647 rows x 7 columns]

# %%
lap_times_stats.describe()
# Out:
#               year    driverId  median_lap_position   total_laps
# count   647.000000  647.000000           647.000000   647.000000
# mean   2008.712519  254.259660            10.000000   831.717156
# std       7.656169  357.613647             4.903401   301.565783
# min    1996.000000    1.000000             1.000000     1.000000
# 25%    2002.000000   17.000000             6.000000   710.000000
# 50%    2009.000000   39.000000            10.000000   902.000000
# 75%    2015.000000  811.500000            14.000000  1043.500000
# max    2022.000000  856.000000            22.000000  1294.000000

# %%
pit_stop_stats = get_pit_stop_stats_in_miliseconds(conn)
print(pit_stop_stats)
# Out:
#      driverId  year  min_pit_stop_time   avg_pit_time  max_pit_stop_time
# 0           1  2011              13173   22666.446429              35688
# 1           1  2012              17598   22671.861111              31081
# 2           1  2013              17385   22399.111111              30085
# 3           1  2014              19710   53061.974359            1137295
# 4           1  2015              16579   23666.000000              30216
# ..        ...   ...                ...            ...                ...
# 270       853  2021              15054  211286.047619            2076977
# 271       854  2021              15058  201851.200000            2075728
# 272       854  2022              14144  111302.675000            3065174
# 273       855  2022              14128   67903.444444            1174235
# 274       856  2022              24628   24628.000000              24628
#
# [275 rows x 5 columns]

# %%
columns_to_discretize = ['min_pit_stop_time', 'avg_pit_time', 'max_pit_stop_time']
labels = ['0-25%', '25-50%', '50% and more']

for col in columns_to_discretize:
    if col in pit_stop_stats.columns:
        bin_edges = [pit_stop_stats[col].min(), pit_stop_stats[col].quantile(0.25), pit_stop_stats[col].quantile(0.5), pit_stop_stats[col].max()]
        pit_stop_stats[col] = pd.cut(pit_stop_stats[col], bins=bin_edges, include_lowest=True, duplicates='drop', labels=labels)

print(pit_stop_stats)
# Out:
#      driverId  year min_pit_stop_time  avg_pit_time max_pit_stop_time
# 0           1  2011             0-25%         0-25%            25-50%
# 1           1  2012            25-50%         0-25%             0-25%
# 2           1  2013            25-50%         0-25%             0-25%
# 3           1  2014      50% and more  50% and more      50% and more
# 4           1  2015            25-50%         0-25%             0-25%
# ..        ...   ...               ...           ...               ...
# 270       853  2021             0-25%  50% and more      50% and more
# 271       854  2021             0-25%  50% and more      50% and more
# 272       854  2022             0-25%  50% and more      50% and more
# 273       855  2022             0-25%  50% and more      50% and more
# 274       856  2022      50% and more        25-50%             0-25%
#
# [275 rows x 5 columns]

# %%
most_common_pit_stop_lap = get_most_common_pit_stop_lap(conn)
pit_stop_stats = pd.merge(pit_stop_stats, most_common_pit_stop_lap, on=['driverId', 'year'], how='left')
print(pit_stop_stats)
# Out:
#      driverId  year min_pit_stop_time  avg_pit_time max_pit_stop_time  \
# 0           1  2011             0-25%         0-25%            25-50%
# 1           1  2012            25-50%         0-25%             0-25%
# 2           1  2013            25-50%         0-25%             0-25%
# 3           1  2014      50% and more  50% and more      50% and more
# 4           1  2015            25-50%         0-25%             0-25%
# ..        ...   ...               ...           ...               ...
# 270       853  2021             0-25%  50% and more      50% and more
# 271       854  2021             0-25%  50% and more      50% and more
# 272       854  2022             0-25%  50% and more      50% and more
# 273       855  2022             0-25%  50% and more      50% and more
# 274       856  2022      50% and more        25-50%             0-25%
#
#      most_common_pitstop_lap
# 0                         16
# 1                         36
# 2                         31
# 3                         26
# 4                         13
# ..                       ...
# 270                       31
# 271                       34
# 272                       14
# 273                        9
# 274                       19
#
# [275 rows x 6 columns]

# %%
constructor_driver_connection = get_drivers_with_constructor_relationship(conn)

# %%
drivers_with_constructors = pd.merge(drivers_final_positions, constructor_driver_connection, on=['driverId', 'year'], how='left')
print(drivers_with_constructors)
# Out:
#       year  driverId date_of_birth driver_nationality  driver_points  \
# 0     1950       427    1917-10-30             French            0.0
# 1     1950       498    1922-10-05          Argentine            0.0
# 2     1950       501    1921-06-29           American            0.0
# 3     1950       501    1921-06-29           American            0.0
# 4     1950       509    1928-07-16           American            0.0
# ...    ...       ...           ...                ...            ...
# 3482  2022       849    1995-06-29           Canadian            2.0
# 3483  2022       852    2000-05-11           Japanese           12.0
# 3484  2022       854    1999-03-22             German           12.0
# 3485  2022       855    1999-05-30            Chinese            6.0
# 3486  2022       856    1995-02-06              Dutch            2.0
#
#       driver_end_position  first_place_count  second_place_count  \
# 0                      23                0.0                 0.0
# 1                      23                0.0                 0.0
# 2                      23                0.0                 0.0
# 3                      23                0.0                 0.0
# 4                      23                0.0                 0.0
# ...                   ...                ...                 ...
# 3482                   20                0.0                 0.0
# 3483                   16                0.0                 0.0
# 3484                   16                0.0                 0.0
# 3485                   18                0.0                 0.0
# 3486                   20                0.0                 0.0
#
#       third_place_count  top_5_count  age_at_first_race  constructorId  \
# 0                   0.0          0.0                 33            141
# 1                   0.0          0.0                 28            105
# 2                   0.0          0.0                 29             87
# 3                   0.0          0.0                 29            154
# 4                   0.0          0.0                 22            160
# ...                 ...          ...                ...            ...
# 3482                0.0          0.0                 25              3
# 3483                0.0          0.0                 21            213
# 3484                0.0          0.0                 22            210
# 3485                0.0          0.0                 23             51
# 3486                0.0          0.0                 27              3
#
#      constructorName constructor_nationality
# 0              Simca                  French
# 1           Maserati                 Italian
# 2             Cooper                 British
# 3        Talbot-Lago                  French
# 4          Wetteroth                American
# ...              ...                     ...
# 3482        Williams                 British
# 3483      AlphaTauri                 Italian
# 3484    Haas F1 Team                American
# 3485      Alfa Romeo                   Swiss
# 3486        Williams                 British
#
# [3487 rows x 14 columns]

# %%
connstructor_points = get_constructor_points(conn)
print(connstructor_points)
# Out:
#      year  constructorId  constructor_points  constructor_place
# 0    2022              9               759.0                  1
# 1    2022              6               554.0                  2
# 2    2022            131               515.0                  3
# 3    2022            214               173.0                  4
# 4    2022              1               159.0                  5
# ..    ...            ...                 ...                ...
# 895  1958            105                 6.0                  5
# 896  1958             32                 3.0                  6
# 897  1958            125                 0.0                  7
# 898  1958            127                 0.0                  7
# 899  1958             95                 0.0                  7
#
# [900 rows x 4 columns]

# %%
connstructor_points = connstructor_points.sort_values(by=['year', 'constructorId'])

for index, row in connstructor_points.iterrows():
    temp_df = connstructor_points[(connstructor_points['constructorId'] == row['constructorId']) & (connstructor_points['year'] <= row['year'])]
    
    temp_first_place_count = temp_df[temp_df['constructor_place'] == 1].shape[0]
    temp_second_place_count = temp_df[temp_df['constructor_place'] == 2].shape[0]
    temp_third_place_count = temp_df[temp_df['constructor_place'] == 3].shape[0]
    temp_top_5_count = temp_df[temp_df['constructor_place'] <= 5].shape[0]
    
    connstructor_points.at[index, 'constructor_first_place_count'] = temp_first_place_count
    connstructor_points.at[index, 'constructor_second_place_count'] = temp_second_place_count
    connstructor_points.at[index, 'constructor_third_place_count'] = temp_third_place_count
    connstructor_points.at[index, 'constructor_top_5_count'] = temp_top_5_count

print(connstructor_points)
# Out:
#      year  constructorId  constructor_points  constructor_place  \
# 892  1958              6                40.0                  2
# 896  1958             32                 3.0                  6
# 894  1958             66                18.0                  4
# 893  1958             87                31.0                  3
# 899  1958             95                 0.0                  7
# ..    ...            ...                 ...                ...
# 6    2022            117                55.0                  6
# 2    2022            131               515.0                  3
# 7    2022            210                37.0                  8
# 8    2022            213                35.0                  9
# 3    2022            214               173.0                  4
#
#      constructor_first_place_count  constructor_second_place_count  \
# 892                            0.0                             1.0
# 896                            0.0                             0.0
# 894                            0.0                             0.0
# 893                            0.0                             0.0
# 899                            0.0                             0.0
# ..                             ...                             ...
# 6                              0.0                             0.0
# 2                              8.0                             1.0
# 7                              0.0                             0.0
# 8                              0.0                             0.0
# 3                              0.0                             0.0
#
#      constructor_third_place_count  constructor_top_5_count
# 892                            0.0                      1.0
# 896                            0.0                      0.0
# 894                            0.0                      1.0
# 893                            1.0                      1.0
# 899                            0.0                      0.0
# ..                             ...                      ...
# 6                              0.0                      1.0
# 2                              1.0                     13.0
# 7                              0.0                      1.0
# 8                              0.0                      0.0
# 3                              0.0                      2.0
#
# [900 rows x 8 columns]

# %%
drivers_with_constructors = pd.merge(drivers_with_constructors, connstructor_points, on=['constructorId', 'year'], how='left')
print(drivers_with_constructors)
# Out:
#       year  driverId date_of_birth driver_nationality  driver_points  \
# 0     1950       427    1917-10-30             French            0.0
# 1     1950       498    1922-10-05          Argentine            0.0
# 2     1950       501    1921-06-29           American            0.0
# 3     1950       501    1921-06-29           American            0.0
# 4     1950       509    1928-07-16           American            0.0
# ...    ...       ...           ...                ...            ...
# 3482  2022       849    1995-06-29           Canadian            2.0
# 3483  2022       852    2000-05-11           Japanese           12.0
# 3484  2022       854    1999-03-22             German           12.0
# 3485  2022       855    1999-05-30            Chinese            6.0
# 3486  2022       856    1995-02-06              Dutch            2.0
#
#       driver_end_position  first_place_count  second_place_count  \
# 0                      23                0.0                 0.0
# 1                      23                0.0                 0.0
# 2                      23                0.0                 0.0
# 3                      23                0.0                 0.0
# 4                      23                0.0                 0.0
# ...                   ...                ...                 ...
# 3482                   20                0.0                 0.0
# 3483                   16                0.0                 0.0
# 3484                   16                0.0                 0.0
# 3485                   18                0.0                 0.0
# 3486                   20                0.0                 0.0
#
#       third_place_count  top_5_count  age_at_first_race  constructorId  \
# 0                   0.0          0.0                 33            141
# 1                   0.0          0.0                 28            105
# 2                   0.0          0.0                 29             87
# 3                   0.0          0.0                 29            154
# 4                   0.0          0.0                 22            160
# ...                 ...          ...                ...            ...
# 3482                0.0          0.0                 25              3
# 3483                0.0          0.0                 21            213
# 3484                0.0          0.0                 22            210
# 3485                0.0          0.0                 23             51
# 3486                0.0          0.0                 27              3
#
#      constructorName constructor_nationality  constructor_points  \
# 0              Simca                  French                 NaN
# 1           Maserati                 Italian                 NaN
# 2             Cooper                 British                 NaN
# 3        Talbot-Lago                  French                 NaN
# 4          Wetteroth                American                 NaN
# ...              ...                     ...                 ...
# 3482        Williams                 British                 8.0
# 3483      AlphaTauri                 Italian                35.0
# 3484    Haas F1 Team                American                37.0
# 3485      Alfa Romeo                   Swiss                55.0
# 3486        Williams                 British                 8.0
#
#       constructor_place  constructor_first_place_count  \
# 0                   NaN                            NaN
# 1                   NaN                            NaN
# 2                   NaN                            NaN
# 3                   NaN                            NaN
# 4                   NaN                            NaN
# ...                 ...                            ...
# 3482               10.0                            9.0
# 3483                9.0                            0.0
# 3484                8.0                            0.0
# 3485                6.0                            0.0
# 3486               10.0                            9.0
#
#       constructor_second_place_count  constructor_third_place_count  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 3482                             6.0                            6.0
# 3483                             0.0                            0.0
# 3484                             0.0                            0.0
# 3485                             0.0                            0.0
# 3486                             6.0                            6.0
#
#       constructor_top_5_count
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 3482                     30.0
# 3483                      0.0
# 3484                      1.0
# 3485                      0.0
# 3486                     30.0
#
# [3487 rows x 20 columns]

# %%
best_performing_circuits = get_best_performing_circuits(conn)
drivers_with_constructors = pd.merge(drivers_with_constructors, best_performing_circuits, on=['year','driverId' ], how='left')
print(drivers_with_constructors)
# Out:
#       year  driverId date_of_birth driver_nationality  driver_points  \
# 0     1950       427    1917-10-30             French            0.0
# 1     1950       498    1922-10-05          Argentine            0.0
# 2     1950       501    1921-06-29           American            0.0
# 3     1950       501    1921-06-29           American            0.0
# 4     1950       509    1928-07-16           American            0.0
# ...    ...       ...           ...                ...            ...
# 3482  2022       849    1995-06-29           Canadian            2.0
# 3483  2022       852    2000-05-11           Japanese           12.0
# 3484  2022       854    1999-03-22             German           12.0
# 3485  2022       855    1999-05-30            Chinese            6.0
# 3486  2022       856    1995-02-06              Dutch            2.0
#
#       driver_end_position  first_place_count  second_place_count  \
# 0                      23                0.0                 0.0
# 1                      23                0.0                 0.0
# 2                      23                0.0                 0.0
# 3                      23                0.0                 0.0
# 4                      23                0.0                 0.0
# ...                   ...                ...                 ...
# 3482                   20                0.0                 0.0
# 3483                   16                0.0                 0.0
# 3484                   16                0.0                 0.0
# 3485                   18                0.0                 0.0
# 3486                   20                0.0                 0.0
#
#       third_place_count  top_5_count  ...  constructorId  constructorName  \
# 0                   0.0          0.0  ...            141            Simca
# 1                   0.0          0.0  ...            105         Maserati
# 2                   0.0          0.0  ...             87           Cooper
# 3                   0.0          0.0  ...            154      Talbot-Lago
# 4                   0.0          0.0  ...            160        Wetteroth
# ...                 ...          ...  ...            ...              ...
# 3482                0.0          0.0  ...              3         Williams
# 3483                0.0          0.0  ...            213       AlphaTauri
# 3484                0.0          0.0  ...            210     Haas F1 Team
# 3485                0.0          0.0  ...             51       Alfa Romeo
# 3486                0.0          0.0  ...              3         Williams
#
#      constructor_nationality constructor_points  constructor_place  \
# 0                     French                NaN                NaN
# 1                    Italian                NaN                NaN
# 2                    British                NaN                NaN
# 3                     French                NaN                NaN
# 4                   American                NaN                NaN
# ...                      ...                ...                ...
# 3482                 British                8.0               10.0
# 3483                 Italian               35.0                9.0
# 3484                American               37.0                8.0
# 3485                   Swiss               55.0                6.0
# 3486                 British                8.0               10.0
#
#       constructor_first_place_count  constructor_second_place_count  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# ...                             ...                             ...
# 3482                            9.0                             6.0
# 3483                            0.0                             0.0
# 3484                            0.0                             0.0
# 3485                            0.0                             0.0
# 3486                            9.0                             6.0
#
#       constructor_third_place_count  constructor_top_5_count  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
# ...                             ...                      ...
# 3482                            6.0                     30.0
# 3483                            0.0                      0.0
# 3484                            0.0                      1.0
# 3485                            0.0                      0.0
# 3486                            6.0                     30.0
#
#        best_performing_circuit_name
# 0                 Circuit de Monaco
# 1                 Circuit de Monaco
# 2                 Circuit de Monaco
# 3                 Circuit de Monaco
# 4       Indianapolis Motor Speedway
# ...                             ...
# 3482                 Suzuka Circuit
# 3483  Autodromo Enzo e Dino Ferrari
# 3484                  Red Bull Ring
# 3485      Circuit Gilles Villeneuve
# 3486   Autodromo Nazionale di Monza
#
# [3487 rows x 21 columns]

# %%
lap_pit_df = pd.merge(lap_times_stats, pit_stop_stats, on=['driverId', 'year'], how='left', suffixes=('_lap', '_pit'))

print(lap_pit_df)
# Out:
#      year  driverId min_lap_time_diff avg_lap_time_diff max_lap_time_diff  \
# 0    2007         1             0-25%            25-50%      50% and more
# 1    2008         1             0-25%            25-50%            25-50%
# 2    2009         1             0-25%             0-25%             0-25%
# 3    2010         1             0-25%      50% and more      50% and more
# 4    2011         1             0-25%            25-50%      50% and more
# ..    ...       ...               ...               ...               ...
# 642  2021       853      50% and more      50% and more      50% and more
# 643  2021       854      50% and more      50% and more      50% and more
# 644  2022       854            25-50%      50% and more      50% and more
# 645  2022       855             0-25%      50% and more      50% and more
# 646  2022       856      50% and more            25-50%             0-25%
#
#      median_lap_position  total_laps min_pit_stop_time  avg_pit_time  \
# 0                      2        1037               NaN           NaN
# 1                      3        1065               NaN           NaN
# 2                      7         904               NaN           NaN
# 3                      4        1001               NaN           NaN
# 4                      4        1013             0-25%         0-25%
# ..                   ...         ...               ...           ...
# 642                   18        1008             0-25%  50% and more
# 643                   18        1135             0-25%  50% and more
# 644                   14        1142             0-25%  50% and more
# 645                   14        1060             0-25%  50% and more
# 646                    9          53      50% and more        25-50%
#
#     max_pit_stop_time  most_common_pitstop_lap
# 0                 NaN                      NaN
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4              25-50%                     16.0
# ..                ...                      ...
# 642      50% and more                     31.0
# 643      50% and more                     34.0
# 644      50% and more                     14.0
# 645      50% and more                      9.0
# 646             0-25%                     19.0
#
# [647 rows x 11 columns]

# %%
lap_pit_df.describe()
# Out:
#               year    driverId  median_lap_position   total_laps  \
# count   647.000000  647.000000           647.000000   647.000000
# mean   2008.712519  254.259660            10.000000   831.717156
# std       7.656169  357.613647             4.903401   301.565783
# min    1996.000000    1.000000             1.000000     1.000000
# 25%    2002.000000   17.000000             6.000000   710.000000
# 50%    2009.000000   39.000000            10.000000   902.000000
# 75%    2015.000000  811.500000            14.000000  1043.500000
# max    2022.000000  856.000000            22.000000  1294.000000
#
#        most_common_pitstop_lap
# count               275.000000
# mean                 27.152727
# std                  13.007239
# min                   1.000000
# 25%                  17.000000
# 50%                  28.000000
# 75%                  37.000000
# max                  63.000000

# %%
def categorize_total_laps(laps):
    if laps <= 1000:
        return '0-1000 Laps'
    elif laps <= 3000:
        return '1001-3000 Laps'
    elif laps <= 6000:
        return '3001-6000 Laps'
    elif laps <= 9000:
        return '6001-9000 Laps'
    elif laps <= 12000:
        return '9001-12000 Laps'
    else:
        return 'More than 12000 Laps'

lap_pit_df['total_laps'] = lap_pit_df['total_laps'].apply(categorize_total_laps)

# %%
final_df = pd.merge(drivers_with_constructors, lap_pit_df, on=['driverId', 'year'], how='left')

# %%
final_df
# Out:
#       year  driverId date_of_birth driver_nationality  driver_points  \
# 0     1950       427    1917-10-30             French            0.0
# 1     1950       498    1922-10-05          Argentine            0.0
# 2     1950       501    1921-06-29           American            0.0
# 3     1950       501    1921-06-29           American            0.0
# 4     1950       509    1928-07-16           American            0.0
# ...    ...       ...           ...                ...            ...
# 3482  2022       849    1995-06-29           Canadian            2.0
# 3483  2022       852    2000-05-11           Japanese           12.0
# 3484  2022       854    1999-03-22             German           12.0
# 3485  2022       855    1999-05-30            Chinese            6.0
# 3486  2022       856    1995-02-06              Dutch            2.0
#
#       driver_end_position  first_place_count  second_place_count  \
# 0                      23                0.0                 0.0
# 1                      23                0.0                 0.0
# 2                      23                0.0                 0.0
# 3                      23                0.0                 0.0
# 4                      23                0.0                 0.0
# ...                   ...                ...                 ...
# 3482                   20                0.0                 0.0
# 3483                   16                0.0                 0.0
# 3484                   16                0.0                 0.0
# 3485                   18                0.0                 0.0
# 3486                   20                0.0                 0.0
#
#       third_place_count  top_5_count  ...   best_performing_circuit_name  \
# 0                   0.0          0.0  ...              Circuit de Monaco
# 1                   0.0          0.0  ...              Circuit de Monaco
# 2                   0.0          0.0  ...              Circuit de Monaco
# 3                   0.0          0.0  ...              Circuit de Monaco
# 4                   0.0          0.0  ...    Indianapolis Motor Speedway
# ...                 ...          ...  ...                            ...
# 3482                0.0          0.0  ...                 Suzuka Circuit
# 3483                0.0          0.0  ...  Autodromo Enzo e Dino Ferrari
# 3484                0.0          0.0  ...                  Red Bull Ring
# 3485                0.0          0.0  ...      Circuit Gilles Villeneuve
# 3486                0.0          0.0  ...   Autodromo Nazionale di Monza
#
#       min_lap_time_diff avg_lap_time_diff max_lap_time_diff  \
# 0                   NaN               NaN               NaN
# 1                   NaN               NaN               NaN
# 2                   NaN               NaN               NaN
# 3                   NaN               NaN               NaN
# 4                   NaN               NaN               NaN
# ...                 ...               ...               ...
# 3482       50% and more      50% and more      50% and more
# 3483       50% and more      50% and more      50% and more
# 3484             25-50%      50% and more      50% and more
# 3485              0-25%      50% and more      50% and more
# 3486       50% and more            25-50%             0-25%
#
#       median_lap_position      total_laps  min_pit_stop_time  avg_pit_time  \
# 0                     NaN             NaN                NaN           NaN
# 1                     NaN             NaN                NaN           NaN
# 2                     NaN             NaN                NaN           NaN
# 3                     NaN             NaN                NaN           NaN
# 4                     NaN             NaN                NaN           NaN
# ...                   ...             ...                ...           ...
# 3482                 18.0  1001-3000 Laps              0-25%  50% and more
# 3483                 13.0  1001-3000 Laps       50% and more  50% and more
# 3484                 14.0  1001-3000 Laps              0-25%  50% and more
# 3485                 14.0  1001-3000 Laps              0-25%  50% and more
# 3486                  9.0     0-1000 Laps       50% and more        25-50%
#
#       max_pit_stop_time  most_common_pitstop_lap
# 0                   NaN                      NaN
# 1                   NaN                      NaN
# 2                   NaN                      NaN
# 3                   NaN                      NaN
# 4                   NaN                      NaN
# ...                 ...                      ...
# 3482       50% and more                     19.0
# 3483       50% and more                     18.0
# 3484       50% and more                     14.0
# 3485       50% and more                      9.0
# 3486              0-25%                     19.0
#
# [3487 rows x 30 columns]

# %%
final_df.describe()
# Out:
#               year     driverId  driver_points  driver_end_position  \
# count  3487.000000  3487.000000    3487.000000          3487.000000
# mean   1975.854029   356.659019      14.380531            16.701463
# std      20.152251   242.422349      42.375905             7.325131
# min    1950.000000     1.000000       0.000000             1.000000
# 25%    1958.000000   146.500000       0.000000            11.000000
# 50%    1972.000000   341.000000       0.000000            19.000000
# 75%    1990.000000   541.000000       8.000000            22.000000
# max    2022.000000   856.000000     454.000000            30.000000
#
#        first_place_count  second_place_count  third_place_count  top_5_count  \
# count        3487.000000         3487.000000        3487.000000  3487.000000
# mean            0.148839            0.164611           0.134500     0.740465
# std             0.642212            0.558025           0.456332     1.850720
# min             0.000000            0.000000           0.000000     0.000000
# 25%             0.000000            0.000000           0.000000     0.000000
# 50%             0.000000            0.000000           0.000000     0.000000
# 75%             0.000000            0.000000           0.000000     0.000000
# max             7.000000            4.000000           3.000000    15.000000
#
#        age_at_first_race  constructorId  constructor_points  \
# count         3487.00000    3487.000000         2614.000000
# mean            28.17895      74.654718           44.259946
# std              5.98445      62.433290           93.690194
# min             18.00000       1.000000            0.000000
# 25%             24.00000      18.000000            2.000000
# 50%             27.00000      58.000000           14.000000
# 75%             31.00000     114.000000           44.000000
# max             54.00000     214.000000          765.000000
#
#        constructor_place  constructor_first_place_count  \
# count        2614.000000                    2614.000000
# mean            6.486611                       1.367253
# std             3.786143                       2.900535
# min             1.000000                       0.000000
# 25%             3.000000                       0.000000
# 50%             6.000000                       0.000000
# 75%             9.000000                       1.000000
# max            17.000000                      15.000000
#
#        constructor_second_place_count  constructor_third_place_count  \
# count                     2614.000000                    2614.000000
# mean                         1.410099                       1.049732
# std                          3.067575                       1.960530
# min                          0.000000                       0.000000
# 25%                          0.000000                       0.000000
# 50%                          0.000000                       0.000000
# 75%                          1.750000                       1.000000
# max                         21.000000                      12.000000
#
#        constructor_top_5_count  median_lap_position  most_common_pitstop_lap
# count              2614.000000           661.000000               281.000000
# mean                  5.753634            10.010590                27.153025
# std                  10.113541             4.868097                13.036271
# min                   0.000000             1.000000                 1.000000
# 25%                   0.000000             6.000000                17.000000
# 50%                   2.000000            10.000000                28.000000
# 75%                   7.000000            14.000000                37.000000
# max                  62.000000            22.000000                63.000000

# %%
positions = get_most_common_positions(conn)

# %%
positions['most_common_ending_position'] = positions['most_common_ending_position'].replace({'\\N': 'Did Not Finish'})

# %%
positions['most_common_starting_position'] = positions['most_common_starting_position'].replace(0, 'Unknown')

# %%
def categorize_pitstop_lap(lap):
    if lap <= 10:
        return 'Early Pitstop'
    elif lap <= 35:
        return 'Mid-race Pitstop'
    else:
        return 'Late Pitstop'

final_df['most_common_pitstop_lap'] = final_df['most_common_pitstop_lap'].apply(categorize_pitstop_lap)

positions['most_common_starting_position'] = pd.to_numeric(positions['most_common_starting_position'], errors='coerce')
positions['most_common_ending_position'] = pd.to_numeric(positions['most_common_ending_position'], errors='coerce')

def categorize_position(position):
    if position <= 5:
        return 'Top 5'
    elif position <= 10:
        return 'Top 10'
    else:
        return 'Beyond Top 10'

# Apply the function to create new columns
positions['most_common_starting_position'] = positions['most_common_starting_position'].apply(categorize_position)
positions['most_common_ending_position'] = positions['most_common_ending_position'].apply(categorize_position)




print(final_df)

print(positions)
# Out:
#       year  driverId date_of_birth driver_nationality  driver_points  \
# 0     1950       427    1917-10-30             French            0.0
# 1     1950       498    1922-10-05          Argentine            0.0
# 2     1950       501    1921-06-29           American            0.0
# 3     1950       501    1921-06-29           American            0.0
# 4     1950       509    1928-07-16           American            0.0
# ...    ...       ...           ...                ...            ...
# 3482  2022       849    1995-06-29           Canadian            2.0
# 3483  2022       852    2000-05-11           Japanese           12.0
# 3484  2022       854    1999-03-22             German           12.0
# 3485  2022       855    1999-05-30            Chinese            6.0
# 3486  2022       856    1995-02-06              Dutch            2.0
#
#       driver_end_position  first_place_count  second_place_count  \
# 0                      23                0.0                 0.0
# 1                      23                0.0                 0.0
# 2                      23                0.0                 0.0
# 3                      23                0.0                 0.0
# 4                      23                0.0                 0.0
# ...                   ...                ...                 ...
# 3482                   20                0.0                 0.0
# 3483                   16                0.0                 0.0
# 3484                   16                0.0                 0.0
# 3485                   18                0.0                 0.0
# 3486                   20                0.0                 0.0
#
#       third_place_count  top_5_count  ...   best_performing_circuit_name  \
# 0                   0.0          0.0  ...              Circuit de Monaco
# 1                   0.0          0.0  ...              Circuit de Monaco
# 2                   0.0          0.0  ...              Circuit de Monaco
# 3                   0.0          0.0  ...              Circuit de Monaco
# 4                   0.0          0.0  ...    Indianapolis Motor Speedway
# ...                 ...          ...  ...                            ...
# 3482                0.0          0.0  ...                 Suzuka Circuit
# 3483                0.0          0.0  ...  Autodromo Enzo e Dino Ferrari
# 3484                0.0          0.0  ...                  Red Bull Ring
# 3485                0.0          0.0  ...      Circuit Gilles Villeneuve
# 3486                0.0          0.0  ...   Autodromo Nazionale di Monza
#
#       min_lap_time_diff avg_lap_time_diff max_lap_time_diff  \
# 0                   NaN               NaN               NaN
# 1                   NaN               NaN               NaN
# 2                   NaN               NaN               NaN
# 3                   NaN               NaN               NaN
# 4                   NaN               NaN               NaN
# ...                 ...               ...               ...
# 3482       50% and more      50% and more      50% and more
# 3483       50% and more      50% and more      50% and more
# 3484             25-50%      50% and more      50% and more
# 3485              0-25%      50% and more      50% and more
# 3486       50% and more            25-50%             0-25%
#
#       median_lap_position      total_laps  min_pit_stop_time  avg_pit_time  \
# 0                     NaN             NaN                NaN           NaN
# 1                     NaN             NaN                NaN           NaN
# 2                     NaN             NaN                NaN           NaN
# 3                     NaN             NaN                NaN           NaN
# 4                     NaN             NaN                NaN           NaN
# ...                   ...             ...                ...           ...
# 3482                 18.0  1001-3000 Laps              0-25%  50% and more
# 3483                 13.0  1001-3000 Laps       50% and more  50% and more
# 3484                 14.0  1001-3000 Laps              0-25%  50% and more
# 3485                 14.0  1001-3000 Laps              0-25%  50% and more
# 3486                  9.0     0-1000 Laps       50% and more        25-50%
#
#       max_pit_stop_time  most_common_pitstop_lap
# 0                   NaN             Late Pitstop
# 1                   NaN             Late Pitstop
# 2                   NaN             Late Pitstop
# 3                   NaN             Late Pitstop
# 4                   NaN             Late Pitstop
# ...                 ...                      ...
# 3482       50% and more         Mid-race Pitstop
# 3483       50% and more         Mid-race Pitstop
# 3484       50% and more         Mid-race Pitstop
# 3485       50% and more            Early Pitstop
# 3486              0-25%         Mid-race Pitstop
#
# [3487 rows x 30 columns]
#       driverId  year most_common_starting_position most_common_ending_position
# 0            1  2007                         Top 5                       Top 5
# 1            1  2008                         Top 5                       Top 5
# 2            1  2009                 Beyond Top 10               Beyond Top 10
# 3            1  2010                         Top 5                       Top 5
# 4            1  2011                         Top 5                       Top 5
# ...        ...   ...                           ...                         ...
# 3160       853  2021                 Beyond Top 10               Beyond Top 10
# 3161       854  2021                 Beyond Top 10               Beyond Top 10
# 3162       854  2022                 Beyond Top 10               Beyond Top 10
# 3163       855  2022                 Beyond Top 10                      Top 10
# 3164       856  2022                        Top 10                      Top 10
#
# [3165 rows x 4 columns]

# %%
final_df = pd.merge(final_df, positions, on=['driverId', 'year'], how='left')

# %%
final_df.describe()
# Out:
#               year     driverId  driver_points  driver_end_position  \
# count  3487.000000  3487.000000    3487.000000          3487.000000
# mean   1975.854029   356.659019      14.380531            16.701463
# std      20.152251   242.422349      42.375905             7.325131
# min    1950.000000     1.000000       0.000000             1.000000
# 25%    1958.000000   146.500000       0.000000            11.000000
# 50%    1972.000000   341.000000       0.000000            19.000000
# 75%    1990.000000   541.000000       8.000000            22.000000
# max    2022.000000   856.000000     454.000000            30.000000
#
#        first_place_count  second_place_count  third_place_count  top_5_count  \
# count        3487.000000         3487.000000        3487.000000  3487.000000
# mean            0.148839            0.164611           0.134500     0.740465
# std             0.642212            0.558025           0.456332     1.850720
# min             0.000000            0.000000           0.000000     0.000000
# 25%             0.000000            0.000000           0.000000     0.000000
# 50%             0.000000            0.000000           0.000000     0.000000
# 75%             0.000000            0.000000           0.000000     0.000000
# max             7.000000            4.000000           3.000000    15.000000
#
#        age_at_first_race  constructorId  constructor_points  \
# count         3487.00000    3487.000000         2614.000000
# mean            28.17895      74.654718           44.259946
# std              5.98445      62.433290           93.690194
# min             18.00000       1.000000            0.000000
# 25%             24.00000      18.000000            2.000000
# 50%             27.00000      58.000000           14.000000
# 75%             31.00000     114.000000           44.000000
# max             54.00000     214.000000          765.000000
#
#        constructor_place  constructor_first_place_count  \
# count        2614.000000                    2614.000000
# mean            6.486611                       1.367253
# std             3.786143                       2.900535
# min             1.000000                       0.000000
# 25%             3.000000                       0.000000
# 50%             6.000000                       0.000000
# 75%             9.000000                       1.000000
# max            17.000000                      15.000000
#
#        constructor_second_place_count  constructor_third_place_count  \
# count                     2614.000000                    2614.000000
# mean                         1.410099                       1.049732
# std                          3.067575                       1.960530
# min                          0.000000                       0.000000
# 25%                          0.000000                       0.000000
# 50%                          0.000000                       0.000000
# 75%                          1.750000                       1.000000
# max                         21.000000                      12.000000
#
#        constructor_top_5_count  median_lap_position
# count              2614.000000           661.000000
# mean                  5.753634            10.010590
# std                  10.113541             4.868097
# min                   0.000000             1.000000
# 25%                   0.000000             6.000000
# 50%                   2.000000            10.000000
# 75%                   7.000000            14.000000
# max                  62.000000            22.000000

# %%
columns_to_fill_unknown = ['min_lap_time_diff', 'avg_lap_time_diff', 'max_lap_time_diff', 'min_pit_stop_time', 'avg_pit_time', 'max_pit_stop_time']

final_df[columns_to_fill_unknown] = final_df[columns_to_fill_unknown].astype(str)

final_df[columns_to_fill_unknown] = final_df[columns_to_fill_unknown].applymap(lambda x: 'Unknown' if str(x).lower() == 'nan' else x)

print(final_df)
# Out:
#       year  driverId date_of_birth driver_nationality  driver_points  \
# 0     1950       427    1917-10-30             French            0.0
# 1     1950       498    1922-10-05          Argentine            0.0
# 2     1950       501    1921-06-29           American            0.0
# 3     1950       501    1921-06-29           American            0.0
# 4     1950       509    1928-07-16           American            0.0
# ...    ...       ...           ...                ...            ...
# 3482  2022       849    1995-06-29           Canadian            2.0
# 3483  2022       852    2000-05-11           Japanese           12.0
# 3484  2022       854    1999-03-22             German           12.0
# 3485  2022       855    1999-05-30            Chinese            6.0
# 3486  2022       856    1995-02-06              Dutch            2.0
#
#       driver_end_position  first_place_count  second_place_count  \
# 0                      23                0.0                 0.0
# 1                      23                0.0                 0.0
# 2                      23                0.0                 0.0
# 3                      23                0.0                 0.0
# 4                      23                0.0                 0.0
# ...                   ...                ...                 ...
# 3482                   20                0.0                 0.0
# 3483                   16                0.0                 0.0
# 3484                   16                0.0                 0.0
# 3485                   18                0.0                 0.0
# 3486                   20                0.0                 0.0
#
#       third_place_count  top_5_count  ...  avg_lap_time_diff  \
# 0                   0.0          0.0  ...            Unknown
# 1                   0.0          0.0  ...            Unknown
# 2                   0.0          0.0  ...            Unknown
# 3                   0.0          0.0  ...            Unknown
# 4                   0.0          0.0  ...            Unknown
# ...                 ...          ...  ...                ...
# 3482                0.0          0.0  ...       50% and more
# 3483                0.0          0.0  ...       50% and more
# 3484                0.0          0.0  ...       50% and more
# 3485                0.0          0.0  ...       50% and more
# 3486                0.0          0.0  ...             25-50%
#
#       max_lap_time_diff median_lap_position      total_laps  \
# 0               Unknown                 NaN             NaN
# 1               Unknown                 NaN             NaN
# 2               Unknown                 NaN             NaN
# 3               Unknown                 NaN             NaN
# 4               Unknown                 NaN             NaN
# ...                 ...                 ...             ...
# 3482       50% and more                18.0  1001-3000 Laps
# 3483       50% and more                13.0  1001-3000 Laps
# 3484       50% and more                14.0  1001-3000 Laps
# 3485       50% and more                14.0  1001-3000 Laps
# 3486              0-25%                 9.0     0-1000 Laps
#
#       min_pit_stop_time  avg_pit_time  max_pit_stop_time  \
# 0               Unknown       Unknown            Unknown
# 1               Unknown       Unknown            Unknown
# 2               Unknown       Unknown            Unknown
# 3               Unknown       Unknown            Unknown
# 4               Unknown       Unknown            Unknown
# ...                 ...           ...                ...
# 3482              0-25%  50% and more       50% and more
# 3483       50% and more  50% and more       50% and more
# 3484              0-25%  50% and more       50% and more
# 3485              0-25%  50% and more       50% and more
# 3486       50% and more        25-50%              0-25%
#
#       most_common_pitstop_lap  most_common_starting_position  \
# 0                Late Pitstop                  Beyond Top 10
# 1                Late Pitstop                          Top 5
# 2                Late Pitstop                  Beyond Top 10
# 3                Late Pitstop                  Beyond Top 10
# 4                Late Pitstop                  Beyond Top 10
# ...                       ...                            ...
# 3482         Mid-race Pitstop                  Beyond Top 10
# 3483         Mid-race Pitstop                  Beyond Top 10
# 3484         Mid-race Pitstop                  Beyond Top 10
# 3485            Early Pitstop                  Beyond Top 10
# 3486         Mid-race Pitstop                         Top 10
#
#       most_common_ending_position
# 0                   Beyond Top 10
# 1                   Beyond Top 10
# 2                   Beyond Top 10
# 3                   Beyond Top 10
# 4                   Beyond Top 10
# ...                           ...
# 3482                Beyond Top 10
# 3483                       Top 10
# 3484                Beyond Top 10
# 3485                       Top 10
# 3486                       Top 10
#
# [3487 rows x 32 columns]

# %%
final_df.fillna('Unknown', inplace=True)

# %%
final_df.to_csv('final-with-pistop-miliseconds-with-unknown-discretized.csv', index=False)

# %%
final_df
# Out:
#       year  driverId date_of_birth driver_nationality  driver_points  \
# 0     1950       427    1917-10-30             French            0.0
# 1     1950       498    1922-10-05          Argentine            0.0
# 2     1950       501    1921-06-29           American            0.0
# 3     1950       501    1921-06-29           American            0.0
# 4     1950       509    1928-07-16           American            0.0
# ...    ...       ...           ...                ...            ...
# 3482  2022       849    1995-06-29           Canadian            2.0
# 3483  2022       852    2000-05-11           Japanese           12.0
# 3484  2022       854    1999-03-22             German           12.0
# 3485  2022       855    1999-05-30            Chinese            6.0
# 3486  2022       856    1995-02-06              Dutch            2.0
#
#       driver_end_position  first_place_count  second_place_count  \
# 0                      23                0.0                 0.0
# 1                      23                0.0                 0.0
# 2                      23                0.0                 0.0
# 3                      23                0.0                 0.0
# 4                      23                0.0                 0.0
# ...                   ...                ...                 ...
# 3482                   20                0.0                 0.0
# 3483                   16                0.0                 0.0
# 3484                   16                0.0                 0.0
# 3485                   18                0.0                 0.0
# 3486                   20                0.0                 0.0
#
#       third_place_count  top_5_count  ...  avg_lap_time_diff  \
# 0                   0.0          0.0  ...            Unknown
# 1                   0.0          0.0  ...            Unknown
# 2                   0.0          0.0  ...            Unknown
# 3                   0.0          0.0  ...            Unknown
# 4                   0.0          0.0  ...            Unknown
# ...                 ...          ...  ...                ...
# 3482                0.0          0.0  ...       50% and more
# 3483                0.0          0.0  ...       50% and more
# 3484                0.0          0.0  ...       50% and more
# 3485                0.0          0.0  ...       50% and more
# 3486                0.0          0.0  ...             25-50%
#
#       max_lap_time_diff median_lap_position      total_laps min_pit_stop_time  \
# 0               Unknown             Unknown         Unknown           Unknown
# 1               Unknown             Unknown         Unknown           Unknown
# 2               Unknown             Unknown         Unknown           Unknown
# 3               Unknown             Unknown         Unknown           Unknown
# 4               Unknown             Unknown         Unknown           Unknown
# ...                 ...                 ...             ...               ...
# 3482       50% and more                18.0  1001-3000 Laps             0-25%
# 3483       50% and more                13.0  1001-3000 Laps      50% and more
# 3484       50% and more                14.0  1001-3000 Laps             0-25%
# 3485       50% and more                14.0  1001-3000 Laps             0-25%
# 3486              0-25%                 9.0     0-1000 Laps      50% and more
#
#       avg_pit_time max_pit_stop_time most_common_pitstop_lap  \
# 0          Unknown           Unknown            Late Pitstop
# 1          Unknown           Unknown            Late Pitstop
# 2          Unknown           Unknown            Late Pitstop
# 3          Unknown           Unknown            Late Pitstop
# 4          Unknown           Unknown            Late Pitstop
# ...            ...               ...                     ...
# 3482  50% and more      50% and more        Mid-race Pitstop
# 3483  50% and more      50% and more        Mid-race Pitstop
# 3484  50% and more      50% and more        Mid-race Pitstop
# 3485  50% and more      50% and more           Early Pitstop
# 3486        25-50%             0-25%        Mid-race Pitstop
#
#      most_common_starting_position most_common_ending_position
# 0                    Beyond Top 10               Beyond Top 10
# 1                            Top 5               Beyond Top 10
# 2                    Beyond Top 10               Beyond Top 10
# 3                    Beyond Top 10               Beyond Top 10
# 4                    Beyond Top 10               Beyond Top 10
# ...                            ...                         ...
# 3482                 Beyond Top 10               Beyond Top 10
# 3483                 Beyond Top 10                      Top 10
# 3484                 Beyond Top 10               Beyond Top 10
# 3485                 Beyond Top 10                      Top 10
# 3486                        Top 10                      Top 10
#
# [3487 rows x 32 columns]

# %%
df = final_df.sort_values(by='year', ascending=False)
df = df.astype(str)

numeric_columns = ['year','driver_points', 'driver_end_position', 'constructor_points', 'constructor_place','median_lap_position', 'total_laps']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

aggregation_functions = {
    'year': 'max',
    #'date_of_birth': 'first',
    'driver_nationality': 'first',
    'age_at_first_race': 'first',
    #'driver_end_position': lambda x: round(x.mean()) if x.notna().any() else 'Unknown',
    'first_place_count': 'first',
    'second_place_count': 'first',
    'third_place_count': 'first',
    'top_5_count': 'first',
    'constructorName': 'first',
    'constructor_nationality': 'first',
    #'constructor_place': lambda x: round(x.mean()) if x.notna().any() else 'Unknown',
    'constructor_first_place_count': 'first',
    'constructor_second_place_count': 'first',
    'constructor_third_place_count': 'first',
    'constructor_top_5_count': 'first',
    'best_performing_circuit_name': lambda x: x.mode().iloc[0], 
    'min_lap_time_diff': lambda x: x.mode().iloc[0],
    'avg_lap_time_diff': lambda x: x.mode().iloc[0],
    'max_lap_time_diff': lambda x: x.mode().iloc[0],
    'median_lap_position':lambda x: round(x.mean()) if x.notna().any() else 'Unknown',
    'total_laps': lambda x: round(x.sum()) if x.notna().any() else 'Unknown',
    'min_pit_stop_time': lambda x: x.mode().iloc[0],
    'avg_pit_time': lambda x: x.mode().iloc[0],
    'max_pit_stop_time': lambda x: x.mode().iloc[0],
    'most_common_pitstop_lap': lambda x: x.mode().iloc[0],
    'most_common_starting_position': lambda x: x.mode().iloc[0] if x.notna().any() else 'Unknown',
    'most_common_ending_position': lambda x: x.mode().iloc[0] 
}

aggregated_df = df.groupby('driverId').agg(aggregation_functions)

aggregated_df = aggregated_df.reset_index()

# %%
aggregated_df.fillna('Unknown', inplace=True)

# %%
aggregated_df = aggregated_df.drop('year', axis=1)

# %%
aggregated_df
# Out:
#     driverId driver_nationality age_at_first_race first_place_count  \
# 0          1            British                22               7.0
# 1         10             German                22               0.0
# 2        100             French                28               0.0
# 3        101         Australian                25               0.0
# 4        102          Brazilian                24               3.0
# ..       ...                ...               ...               ...
# 843       95            British                27               1.0
# 844       96             French                26               0.0
# 845       97            Italian                26               0.0
# 846       98              Swiss                31               0.0
# 847       99            Italian                25               0.0
#
#     second_place_count third_place_count top_5_count constructorName  \
# 0                  3.0               0.0        15.0        Mercedes
# 1                  0.0               0.0         0.0        Marussia
# 2                  0.0               0.0         0.0       Larrousse
# 3                  0.0               0.0         0.0          Simtek
# 4                  2.0               1.0         9.0        Williams
# ..                 ...               ...         ...             ...
# 843                3.0               0.0         6.0         McLaren
# 844                0.0               0.0         0.0          Sauber
# 845                0.0               0.0         0.0        Footwork
# 846                0.0               0.0         0.0         Pacific
# 847                0.0               0.0         0.0         Tyrrell
#
#     constructor_nationality constructor_first_place_count  ...  \
# 0                    German                           8.0  ...
# 1                   Russian                           0.0  ...
# 2                    French                           0.0  ...
# 3                   British                           0.0  ...
# 4                   British                           7.0  ...
# ..                      ...                           ...  ...
# 843                 British                           7.0  ...
# 844                   Swiss                           0.0  ...
# 845                 British                           0.0  ...
# 846                 British                           0.0  ...
# 847                 British                           1.0  ...
#
#     avg_lap_time_diff max_lap_time_diff median_lap_position total_laps  \
# 0        50% and more      50% and more                   3    Unknown
# 1        50% and more      50% and more                  15    Unknown
# 2             Unknown           Unknown             Unknown    Unknown
# 3             Unknown           Unknown             Unknown    Unknown
# 4             Unknown           Unknown             Unknown    Unknown
# ..                ...               ...                 ...        ...
# 843           Unknown           Unknown             Unknown    Unknown
# 844           Unknown           Unknown             Unknown    Unknown
# 845           Unknown           Unknown             Unknown    Unknown
# 846           Unknown           Unknown             Unknown    Unknown
# 847           Unknown           Unknown             Unknown    Unknown
#
#     min_pit_stop_time  avg_pit_time max_pit_stop_time most_common_pitstop_lap  \
# 0              25-50%  50% and more      50% and more        Mid-race Pitstop
# 1             Unknown       Unknown           Unknown            Late Pitstop
# 2             Unknown       Unknown           Unknown            Late Pitstop
# 3             Unknown       Unknown           Unknown            Late Pitstop
# 4             Unknown       Unknown           Unknown            Late Pitstop
# ..                ...           ...               ...                     ...
# 843           Unknown       Unknown           Unknown            Late Pitstop
# 844           Unknown       Unknown           Unknown            Late Pitstop
# 845           Unknown       Unknown           Unknown            Late Pitstop
# 846           Unknown       Unknown           Unknown            Late Pitstop
# 847           Unknown       Unknown           Unknown            Late Pitstop
#
#     most_common_starting_position most_common_ending_position
# 0                           Top 5                       Top 5
# 1                   Beyond Top 10               Beyond Top 10
# 2                   Beyond Top 10               Beyond Top 10
# 3                   Beyond Top 10               Beyond Top 10
# 4                           Top 5               Beyond Top 10
# ..                            ...                         ...
# 843                         Top 5               Beyond Top 10
# 844                 Beyond Top 10                      Top 10
# 845                 Beyond Top 10               Beyond Top 10
# 846                 Beyond Top 10               Beyond Top 10
# 847                 Beyond Top 10               Beyond Top 10
#
# [848 rows x 25 columns]

# %%
#aggregated_df = aggregated_df[aggregated_df.ne('Unknown').any(axis=1)]

# %%
#aggregated_df.replace('Unknown', pd.NA, inplace=True)
#aggregated_df.dropna(inplace=True)

# %%
aggregated_df
# Out:
#     driverId driver_nationality age_at_first_race first_place_count  \
# 0          1            British                22               7.0
# 1         10             German                22               0.0
# 2        100             French                28               0.0
# 3        101         Australian                25               0.0
# 4        102          Brazilian                24               3.0
# ..       ...                ...               ...               ...
# 843       95            British                27               1.0
# 844       96             French                26               0.0
# 845       97            Italian                26               0.0
# 846       98              Swiss                31               0.0
# 847       99            Italian                25               0.0
#
#     second_place_count third_place_count top_5_count constructorName  \
# 0                  3.0               0.0        15.0        Mercedes
# 1                  0.0               0.0         0.0        Marussia
# 2                  0.0               0.0         0.0       Larrousse
# 3                  0.0               0.0         0.0          Simtek
# 4                  2.0               1.0         9.0        Williams
# ..                 ...               ...         ...             ...
# 843                3.0               0.0         6.0         McLaren
# 844                0.0               0.0         0.0          Sauber
# 845                0.0               0.0         0.0        Footwork
# 846                0.0               0.0         0.0         Pacific
# 847                0.0               0.0         0.0         Tyrrell
#
#     constructor_nationality constructor_first_place_count  ...  \
# 0                    German                           8.0  ...
# 1                   Russian                           0.0  ...
# 2                    French                           0.0  ...
# 3                   British                           0.0  ...
# 4                   British                           7.0  ...
# ..                      ...                           ...  ...
# 843                 British                           7.0  ...
# 844                   Swiss                           0.0  ...
# 845                 British                           0.0  ...
# 846                 British                           0.0  ...
# 847                 British                           1.0  ...
#
#     avg_lap_time_diff max_lap_time_diff median_lap_position total_laps  \
# 0        50% and more      50% and more                   3    Unknown
# 1        50% and more      50% and more                  15    Unknown
# 2             Unknown           Unknown             Unknown    Unknown
# 3             Unknown           Unknown             Unknown    Unknown
# 4             Unknown           Unknown             Unknown    Unknown
# ..                ...               ...                 ...        ...
# 843           Unknown           Unknown             Unknown    Unknown
# 844           Unknown           Unknown             Unknown    Unknown
# 845           Unknown           Unknown             Unknown    Unknown
# 846           Unknown           Unknown             Unknown    Unknown
# 847           Unknown           Unknown             Unknown    Unknown
#
#     min_pit_stop_time  avg_pit_time max_pit_stop_time most_common_pitstop_lap  \
# 0              25-50%  50% and more      50% and more        Mid-race Pitstop
# 1             Unknown       Unknown           Unknown            Late Pitstop
# 2             Unknown       Unknown           Unknown            Late Pitstop
# 3             Unknown       Unknown           Unknown            Late Pitstop
# 4             Unknown       Unknown           Unknown            Late Pitstop
# ..                ...           ...               ...                     ...
# 843           Unknown       Unknown           Unknown            Late Pitstop
# 844           Unknown       Unknown           Unknown            Late Pitstop
# 845           Unknown       Unknown           Unknown            Late Pitstop
# 846           Unknown       Unknown           Unknown            Late Pitstop
# 847           Unknown       Unknown           Unknown            Late Pitstop
#
#     most_common_starting_position most_common_ending_position
# 0                           Top 5                       Top 5
# 1                   Beyond Top 10               Beyond Top 10
# 2                   Beyond Top 10               Beyond Top 10
# 3                   Beyond Top 10               Beyond Top 10
# 4                           Top 5               Beyond Top 10
# ..                            ...                         ...
# 843                         Top 5               Beyond Top 10
# 844                 Beyond Top 10                      Top 10
# 845                 Beyond Top 10               Beyond Top 10
# 846                 Beyond Top 10               Beyond Top 10
# 847                 Beyond Top 10               Beyond Top 10
#
# [848 rows x 25 columns]

# %%
aggregated_df.to_csv("aggregated.csv", index=False, encoding='utf-8')
